# %%
import pandas as pd
import googlemaps
import simplejson
# note this file is created using the following tutorial https://www.linkedin.com/pulse/calculating-distances-using-python-google-maps-r%C3%A9gis-nisengwe/

# %%
path="/Users/sophieayling/Library/CloudStorage/GoogleDrive-sophie2ayling@gmail.com/My Drive/PhD/08_Fieldwork/07_GPS tracking/Selbourne reports/"
data = pd.read_excel(path+'device_1/HTK913-04612-History+route+details.xlsx')

data['lat_S']=data['Lat'].astype(str).str.strip()
data['lon_S']=data['Lon'].astype(str).str.strip()
data['coordinates']=data['lat_S']+','+ data['lon_S']
data.head()
# Out:
#    No.       Position time       Lat       Lon  Speed  Direction Track way  \
# 0    1 2023-06-17 08:37:34 -18.57565  32.64453    0.0        200       GPS
# 1    2 2023-06-17 08:42:33 -18.57567  32.64477    0.0         99       GPS
# 2    3 2023-06-17 08:50:18 -18.57567  32.64477    0.0         99       GPS
# 3    4 2023-06-17 08:51:09 -18.57564  32.64474    0.0          0       GPS
# 4    5 2023-06-17 08:52:09 -18.57566  32.64475    0.0          0       GPS
#
#        lat_S     lon_S         coordinates
# 0  -18.57565  32.64453  -18.57565,32.64453
# 1  -18.57567  32.64477  -18.57567,32.64477
# 2  -18.57567  32.64477  -18.57567,32.64477
# 3  -18.57564  32.64474  -18.57564,32.64474
# 4  -18.57566  32.64475  -18.57566,32.64475

# %%
API_key="AIzaSyA6aJKuVyulULKdeZY6wytGpS1YdLJKNh4"

gmaps = googlemaps.Client(key=API_key)

# %%
origin = (-18.57565,32.64453)
destinations =data.coordinates

actual_duration = []


for destination in destinations:
    result = gmaps.distance_matrix(origin, destination, mode='driving')["rows"][0]["elements"][0]["duration"]["value"]  
    result = result/3600
    actual_duration.append(result)
    


#Add the list of coordinates to the main data set

data["duration (Hours)"] = actual_duration


data.head(10)
# Out:
#    No.       Position time       Lat       Lon  Speed  Direction Track way  \
# 0    1 2023-06-17 08:37:34 -18.57565  32.64453    0.0        200       GPS
# 1    2 2023-06-17 08:42:33 -18.57567  32.64477    0.0         99       GPS
# 2    3 2023-06-17 08:50:18 -18.57567  32.64477    0.0         99       GPS
# 3    4 2023-06-17 08:51:09 -18.57564  32.64474    0.0          0       GPS
# 4    5 2023-06-17 08:52:09 -18.57566  32.64475    0.0          0       GPS
# 5    6 2023-06-17 08:53:09 -18.57566  32.64475    0.0          0       GPS
# 6    7 2023-06-17 08:56:31 -18.57566  32.64475    0.0          0       GPS
# 7    8 2023-06-17 08:57:19 -18.57563  32.64481    0.0          0       GPS
# 8    9 2023-06-17 08:58:19 -18.57563  32.64478    0.0          0       GPS
# 9   10 2023-06-17 08:59:02 -18.57559  32.64479    0.0          0       GPS
#
#        lat_S     lon_S         coordinates  duration (Hours)
# 0  -18.57565  32.64453  -18.57565,32.64453               0.0
# ...

# %%
origin = (-18.57565,32.64453) 
destinations = data.coordinates


actual_distance = []


for destination in destinations:
    result = gmaps.distance_matrix(origin, destination, mode='driving')["rows"][0]["elements"][0]["distance"]["value"]  
    result = result # now in meters instead
    actual_distance.append(result)
    


#Add the list of coordinates to the main data set

data["distance (m)"] = actual_distance


data.head(15)
# Out:
#     No.       Position time       Lat       Lon  Speed  Direction Track way  \
# 0     1 2023-06-17 08:37:34 -18.57565  32.64453    0.0        200       GPS
# 1     2 2023-06-17 08:42:33 -18.57567  32.64477    0.0         99       GPS
# 2     3 2023-06-17 08:50:18 -18.57567  32.64477    0.0         99       GPS
# 3     4 2023-06-17 08:51:09 -18.57564  32.64474    0.0          0       GPS
# 4     5 2023-06-17 08:52:09 -18.57566  32.64475    0.0          0       GPS
# 5     6 2023-06-17 08:53:09 -18.57566  32.64475    0.0          0       GPS
# 6     7 2023-06-17 08:56:31 -18.57566  32.64475    0.0          0       GPS
# 7     8 2023-06-17 08:57:19 -18.57563  32.64481    0.0          0       GPS
# 8     9 2023-06-17 08:58:19 -18.57563  32.64478    0.0          0       GPS
# 9    10 2023-06-17 08:59:02 -18.57559  32.64479    0.0          0       GPS
# 10   11 2023-06-17 15:22:35 -18.57566  32.64477    0.0          0       GPS
# ...
